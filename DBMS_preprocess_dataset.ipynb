# %%
import pandas as pd

# %%
df = pd.read_csv('salaries.csv')

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT             Data Scientist
# 1          2023               MI              FT  Machine Learning Engineer
# 2          2023               MI              FT               Data Analyst
# 3          2023               MI              FT               Data Analyst
# 4          2023               SE              FT              ETL Developer
# ...         ...              ...             ...                        ...
# 7361       2020               SE              FT             Data Scientist
# 7362       2021               MI              FT   Principal Data Scientist
# 7363       2020               EN              FT             Data Scientist
# 7364       2020               EN              CT      Business Data Analyst
# 7365       2021               SE              FT       Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      100000             USD         100000                 US           100
# 1       45000             EUR          48585                 IT           100
# 2      142000             USD         142000                 US             0
# 3      128000             USD         128000                 US             0
# 4       99500             USD          99500                 US             0
# ...       ...             ...            ...                ...           ...
# 7361   412000             USD         412000                 US           100
# 7362   151000             USD         151000                 US           100
# 7363   105000             USD         105000                 US           100
# 7364   100000             USD         100000                 US           100
# 7365  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  US            M
# 1                  GB            M
# 2                  US            M
# 3                  US            M
# 4                  US            M
# ...               ...          ...
# 7361               US            L
# 7362               US            L
# 7363               US            S
# 7364               US            L
# 7365               IN            L
#
# [7366 rows x 11 columns]

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               EN              FT             Data Scientist
# 1       2023               MI              FT  Machine Learning Engineer
# 2       2023               MI              FT               Data Analyst
# 3       2023               MI              FT               Data Analyst
# 4       2023               SE              FT              ETL Developer
# 5       2023               SE              FT              ETL Developer
# 6       2023               SE              FT              Data Engineer
# 7       2023               SE              FT              Data Engineer
# 8       2023               SE              FT         Research Scientist
# 9       2023               SE              FT         Research Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  100000             USD         100000                 US           100
# 1   45000             EUR          48585                 IT           100
# 2  142000             USD         142000                 US             0
# 3  128000             USD         128000                 US             0
# 4   99500             USD          99500                 US             0
# 5   53300             USD          53300                 US             0
# 6  210000             USD         210000                 US             0
# 7  165000             USD         165000                 US             0
# 8  172000             USD         172000                 US             0
# 9  125000             USD         125000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               GB            M
# 2               US            M
# 3               US            M
# 4               US            M
# 5               US            M
# 6               US            M
# 7               US            M
# 8               US            M
# 9               US            M

# %%
df.dtypes #check for datatypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.isnull().sum() #Check for missing values
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.duplicated().sum() #Check for duplicates
# Out:
# 2952

# %%
df=df.drop_duplicates() #dropping duplicates

# %%
df.duplicated().sum() #Check for duplicates
# Out:
# 0

# %%
df.to_csv('/Users/apple/Desktop/processed_salaries.csv', index=False)
